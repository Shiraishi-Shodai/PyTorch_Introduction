# %%
# !git config --global user.email "siranosuke1227@gmail.com"
# !git config --global user.name "Shiraishi-Shodai"

# %%
# %cd /content/drive/My Drive/PyTorch_Introduction/
# !git init
! git checkout -b develop
! git branch
# !git remote add origin https://github.com/Shiraishi-Shodai/PyTorch_Introduction.git
# !git remote set-url origin https://Shiraishi-Shodai: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@github.com/PyTorch_Introduction.git
# !git remote -v
# Out:
# /content/drive/My Drive/PyTorch_Introduction
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/My Drive/PyTorch_Introduction/.git/
# Switched to a new branch 'develop'
# origin	https://Shiraishi-Shodai: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@github.com/PyTorch_Introduction.git (fetch)
# origin	https://Shiraishi-Shodai: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@github.com/PyTorch_Introduction.git (push)

# %%
# !git pull origin master
# !git add .
# !git commit -m "data_up"
# Out:
# [develop (root-commit) deb590e] data_up
#  27 files changed, 1016 insertions(+)
#  create mode 100644 Chapter1/pytorch_check.ipynb
#  create mode 100644 Chapter2/2-1_example.ipynb
#  create mode 100644 Chapter2/2-2_example.ipynb
#  create mode 100644 Chapter2/2-4_example.ipynb
#  create mode 100644 Chapter2/2_1practice.ipynb
#  create mode 100644 Chapter3/3.5_example.ipynb
#  create mode 100644 Chapter3/3_10_example.ipynb
#  create mode 100644 Chapter3/3_14_example.ipynb
#  create mode 100644 Chapter3/3_234_example.ipynb
#  create mode 100644 Chapter3/3_7_example.ipynb
#  create mode 100644 Chapter3/3_8_example.ipynb
#  create mode 100644 Chapter3/Untitled0.ipynb
#  create mode 100644 Chapter3/ourpoints.t
#  create mode 100644 Chapter4/4_1_example.ipynb
#  create mode 100644 Chapter8/explanation.ipynb
#  create mode 100644 data/bobby.jpg
#  create mode 100644 data/dell-00.jpg
#  create mode 100644 data/horse.jpg
#  create mode 100644 data/horse2zebra_0.4.0.pth
# ...

# %%
# !git push origin HEAD
# Out:
# remote: Not Found
# fatal: repository 'https://github.com/PyTorch_Introduction.git/' not found

# %%
# !git branch
# !git reset --soft HEAD^
# !git reset HEAD^
# Out:
# * master
# fatal: ambiguous argument 'HEAD^': unknown revision or path not in the working tree.
# Use '--' to separate paths from revisions, like this:
# 'git <command> [<revision>...] -- [<file>...]'
# fatal: ambiguous argument 'HEAD^': unknown revision or path not in the working tree.
# Use '--' to separate paths from revisions, like this:
# 'git <command> [<revision>...] -- [<file>...]'

# %%
# !git checkout -b develop
# !git branch
